# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/kaggle/input/iris-flower-dataset/IRIS.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
df.skew
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.skew of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# ...

# %%
df.kurtosis
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.kurt of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# ...

# %%
def print_feature_mean(feature):
    setosa = df[df['species'] == "Iris-setosa"][feature].mean()
    veriscolor = df[df['species'] == "Iris-veriscolor"][feature].mean()
    virginica = df[df['species'] == "Iris-virginica"][feature].mean()
    print("")
    print(f"Iris-Setosa ")

# %%
df.groupby('species').describe()
# Out:
#                 sepal_length                                               \
#                        count      mean       std  min  25%  50%  75%  max
# species
# Iris-setosa             48.0  5.010417  0.359219  4.3  4.8  5.0  5.2  5.8
# Iris-versicolor         50.0  5.936000  0.516171  4.9  5.6  5.9  6.3  7.0
# Iris-virginica          49.0  6.604082  0.632113  4.9  6.3  6.5  6.9  7.9
#
#                 sepal_width            ... petal_length      petal_width  \
#                       count      mean  ...          75%  max       count
# species                                ...
# Iris-setosa            48.0  3.431250  ...          1.6  1.9        48.0
# Iris-versicolor        50.0  2.770000  ...          4.6  5.1        50.0
# Iris-virginica         49.0  2.979592  ...          5.9  6.9        49.0
#
#
#                      mean       std  min  25%  50%  75%  max
# species
# Iris-setosa      0.250000  0.105185  0.1  0.2  0.2  0.3  0.6
# ...

# %%
import seaborn as sns

# %%
g = sns.FacetGrid(df, col="species")
g.map(sns.histplot, "sepal_length")

# %%
plot = sns.barplot(data=df, x="species", y="sepal_length", errwidth=0)

for i in plot.containers: plot.bar_label(i,)

# %%
p = sns.FacetGrid(df, col="species")
p.map(sns.histplot, "sepal_width")

# %%
plot = sns.barplot(data=df, x="species", y="sepal_width", errwidth=0)

for i in plot.containers: plot.bar_label(i,)

# %%
n = sns.FacetGrid(df, col="species")
n.map(sns.histplot, "petal_length")

# %%
plot = sns.barplot(data=df, x="species", y="petal_length", errwidth=0)

for i in plot.containers: plot.bar_label(i,)

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

df['species'] = LE.fit_transform(df['species'])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [147 rows x 5 columns]

# %%
x = df.drop(columns='species')
y = df['species']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(multi_class='multinomial', solver='lbfgs', C=10)

lr.fit(x_train, y_train)
# Out:
# LogisticRegression(C=10, multi_class='multinomial')

# %%
lr_pred = lr.predict(x_test)
lr_pred
# Out:
# array([2, 1, 2, 0, 2, 0, 1, 0, 2, 0, 0, 1, 2, 1, 2, 1, 0, 1, 2, 0, 0, 2,
#        0, 2, 1, 0, 1, 2, 1, 0, 2, 0, 2, 0, 0, 2, 2, 2, 0, 0, 0, 2, 1, 2,
#        1])

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
def print_accuracy_reports(predictions, labels):
    print("Confusion Matrix:")
    print("")
    print(confusion_matrix(predictions, labels))
    print("")
    print("Classification Report:")
    print("")
    print(classification_report(predictions, labels))

# %%
print_accuracy_reports(lr_pred, y_test)
# Out:
# Confusion Matrix:
#
# [[17  0  0]
#  [ 0 11  0]
#  [ 0  1 16]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       0.92      1.00      0.96        11
#            2       1.00      0.94      0.97        17
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ### Random Forest

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier  
Classifier= RandomForestClassifier(n_estimators= 10)  
Classifier.fit(x_train,y_train)
# Out:
# CPU times: user 234 ms, sys: 31.7 ms, total: 266 ms
# Wall time: 407 ms
# RandomForestClassifier(n_estimators=10)

# %%
y_predrf = Classifier.predict(x_test)
y_predrf
# Out:
# array([2, 1, 2, 0, 1, 0, 1, 0, 2, 0, 0, 1, 2, 1, 2, 1, 0, 1, 2, 0, 0, 2,
#        0, 2, 1, 0, 1, 2, 1, 0, 2, 0, 2, 0, 0, 2, 2, 2, 0, 0, 0, 2, 1, 2,
#        1])

# %%
yt_predrf = Classifier.predict(x_train)
yt_predrf
# Out:
# array([1, 2, 2, 0, 1, 1, 0, 0, 1, 0, 0, 0, 2, 1, 2, 0, 0, 2, 0, 1, 2, 0,
#        1, 2, 0, 1, 2, 1, 2, 1, 1, 0, 2, 1, 1, 0, 1, 1, 0, 2, 0, 0, 1, 1,
#        1, 2, 2, 1, 0, 0, 2, 2, 0, 0, 0, 1, 2, 0, 2, 2, 0, 1, 1, 2, 1, 2,
#        0, 2, 1, 2, 1, 1, 1, 0, 1, 1, 1, 1, 2, 0, 1, 1, 0, 2, 0, 2, 0, 1,
#        2, 2, 2, 2, 1, 1, 2, 2, 0, 1, 2, 0, 1, 2])

# %%
print_accuracy_reports(y_predrf, y_test)
# Out:
# Confusion Matrix:
#
# [[17  0  0]
#  [ 0 11  1]
#  [ 0  1 15]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       0.92      0.92      0.92        12
#            2       0.94      0.94      0.94        16
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
print_accuracy_reports(yt_predrf, y_train)
# Out:
# Confusion Matrix:
#
# [[31  0  0]
#  [ 0 38  0]
#  [ 0  0 33]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       1.00      1.00      1.00        38
#            2       1.00      1.00      1.00        33
#
#     accuracy                           1.00       102
#    macro avg       1.00      1.00      1.00       102
# weighted avg       1.00      1.00      1.00       102

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier  
knn = KNeighborsClassifier(n_neighbors=25,metric='minkowski', p=2 )  
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=25)

# %%
y_predk = knn.predict(x_test)

# %%
yt_predk = knn.predict(x_train)

# %%
print_accuracy_reports(y_predk, y_test)
# Out:
# Confusion Matrix:
#
# [[17  0  0]
#  [ 0 11  2]
#  [ 0  1 14]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       0.92      0.85      0.88        13
#            2       0.88      0.93      0.90        15
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.93      0.93        45
# weighted avg       0.93      0.93      0.93        45

# %%
print_accuracy_reports(yt_predk, y_train)
# Out:
# Confusion Matrix:
#
# [[31  0  0]
#  [ 0 38  2]
#  [ 0  0 31]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       1.00      0.95      0.97        40
#            2       0.94      1.00      0.97        31
#
#     accuracy                           0.98       102
#    macro avg       0.98      0.98      0.98       102
# weighted avg       0.98      0.98      0.98       102

# %%
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt

# Define the number of training examples to use for each iteration
train_sizes, train_scores, test_scores = learning_curve(knn, x_train, y_train, cv=3, train_sizes=np.linspace(0.1, 1.0, 10))

# Calculate the mean and standard deviation of the training and test scores for each iteration
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.plot(train_sizes, train_mean, label='Training score')
plt.plot(train_sizes, test_mean, label='Testing score')

# Add error bands to the plot
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.1)
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.1)

# Add labels and legend to the plot
plt.xlabel('Number of training examples')
plt.ylabel('Score')
plt.title('Learning Curve')
plt.legend(loc='best')

plt.show()
